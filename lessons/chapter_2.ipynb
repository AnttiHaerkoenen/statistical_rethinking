# %%
import numpy as np
import pandas as pd
from scipy.stats import binom
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2M1.

# %%
prior = np.ones(101)
data = {
    'case_1': np.array([3, 0]),
    'case_2': np.array([3, 1]),
    'case_3': np.array([5, 2]),
}
grid = np.linspace(0, 1, 101)

def get_posterior(data, grid, prior):
    likelihood = binom.pmf(data[0], data.sum(), grid)
    unscaled_posterior = likelihood * prior
    posterior = unscaled_posterior / unscaled_posterior.sum()
    return posterior

# %% [markdown]
# ### (1)

# %%
posterior = get_posterior(data['case_1'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ### (2)

# %%
posterior = get_posterior(data['case_2'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ### (3)

# %%
posterior = get_posterior(data['case_3'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ## 2M2.

# %%
prior = np.concatenate([np.zeros(50), np.ones(51)])

# %% [markdown]
# ### (1)

# %%
posterior = get_posterior(data['case_1'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ### (2)

# %%
posterior = get_posterior(data['case_2'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ### (3)

# %%
posterior = get_posterior(data['case_3'], grid, prior)
plt.plot(grid, posterior)
plt.show()

# %% [markdown]
# ## 2M3.

# %%
data = np.array([0, 1])
prior = np.ones(2)
likelihood = np.array([1, 0.3])
unscaled_posterior = likelihood * prior
posterior = unscaled_posterior / unscaled_posterior.sum()
print(np.round(posterior[1], 2))
# Out:
# 0.23

# %% [markdown]
# ## 2H1.

# %%
prior = np.ones(2)
likelihood = np.array([0.1, 0.2])
unscaled_posterior = prior * likelihood
p_species = unscaled_posterior / unscaled_posterior.sum()
p_twins = (likelihood * p_species).sum()
print(np.round(p_twins, 2))
# Out:
# 0.17

# %% [markdown]
# ## 2H2.

# %%
print(np.round(p_species[0], 2))
# Out:
# 0.33

# %% [markdown]
# ## 2H3.

# %%
prior = p_species
likelihood = 1 - likelihood
unscaled_posterior = prior * likelihood
posterior_new = unscaled_posterior / unscaled_posterior.sum()
print(np.round(posterior_new[0], 2))
# Out:
# 0.36

# %% [markdown]
# ## 2H4.

# %%
prior = np.ones(2)
likelihood = np.array([0.8, 0.35])
unscaled_posterior = prior * likelihood
posterior = unscaled_posterior / unscaled_posterior.sum()
print(np.round(posterior[0], 2))

prior = posterior_new
unscaled_posterior = prior * likelihood
posterior = unscaled_posterior / unscaled_posterior.sum()
print(np.round(posterior[0], 2))
# Out:
# 0.7
# 0.56
